# %% [markdown]
# # Pre-requisites

# %%
import pandas as pd
import numpy as np
import requests
import pandas as pd
import json

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##Exploring & Analysing the Churn Modelling Dataset

# %%
df1 = pd.read_csv('/content/drive/MyDrive/DAPDatasets/Churn_Modelling.xls')
df1
df1.head()
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
print(df1.shape)
print(df1.shape[1])
# Out:
# (10000, 14)
# 14

# %%
df1.drop(['RowNumber', 'CustomerId','Surname','CreditScore'], axis=1)
# Out:
#      Geography  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0       France  Female   42       2       0.00              1          1
# 1        Spain  Female   41       1   83807.86              1          0
# 2       France  Female   42       8  159660.80              3          1
# 3       France  Female   39       1       0.00              2          0
# 4        Spain  Female   43       2  125510.82              1          1
# ...        ...     ...  ...     ...        ...            ...        ...
# 9995    France    Male   39       5       0.00              2          1
# 9996    France    Male   35      10   57369.61              1          1
# 9997    France  Female   36       7       0.00              1          0
# 9998   Germany    Male   42       3   75075.31              2          1
# 9999    France  Female   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Exited
# ...

# %%
#df2 = df1('Gender','Age','Tenure','Balance')
#df2 = df1.loc[:,'Gender':'Balance']
#df2
df3 = pd.read_csv("/content/drive/MyDrive/DAPDatasets/Churn_Modelling.xls", usecols = ['Gender','Age','Tenure','Balance'])

# %%
df3
# Out:
#       Gender  Age  Tenure    Balance
# 0     Female   42       2       0.00
# 1     Female   41       1   83807.86
# 2     Female   42       8  159660.80
# 3     Female   39       1       0.00
# 4     Female   43       2  125510.82
# ...      ...  ...     ...        ...
# 9995    Male   39       5       0.00
# 9996    Male   35      10   57369.61
# 9997  Female   36       7       0.00
# 9998    Male   42       3   75075.31
# 9999  Female   28       4  130142.79
#
# [10000 rows x 4 columns]

# %%
df1.head(10)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
# 5          6    15574012       Chu          645     Spain    Male   44
# 6          7    15592531  Bartlett          822    France    Male   50
# 7          8    15656148    Obinna          376   Germany  Female   29
# 8          9    15792365        He          501    France    Male   44
# 9         10    15592389        H?          684    France    Male   27
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# ...

# %%
df4 = pd.read_csv("/content/drive/MyDrive/DAPDatasets/Churn_Modelling.xls", nrows = 20, skiprows = 2)
#using skiprows we skip the rows from the initial row to the index specified
df4
#df1
# Out:
#      2  15647311       Hill  608    Spain  Female  41   1   83807.86  1.1  0  \
# 0    3  15619304       Onio  502   France  Female  42   8  159660.80    3  1
# 1    4  15701354       Boni  699   France  Female  39   1       0.00    2  0
# 2    5  15737888   Mitchell  850    Spain  Female  43   2  125510.82    1  1
# 3    6  15574012        Chu  645    Spain    Male  44   8  113755.78    2  1
# 4    7  15592531   Bartlett  822   France    Male  50   7       0.00    2  1
# 5    8  15656148     Obinna  376  Germany  Female  29   4  115046.74    4  1
# 6    9  15792365         He  501   France    Male  44   4  142051.07    2  0
# 7   10  15592389         H?  684   France    Male  27   2  134603.88    1  1
# 8   11  15767821     Bearce  528   France    Male  31   6  102016.72    2  0
# 9   12  15737173    Andrews  497    Spain    Male  24   3       0.00    2  1
# 10  13  15632264        Kay  476   France  Female  34  10       0.00    2  1
# ...

# %%
df1.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
missing_index = np.random.randint(10000, size=20)
df1miss = df1.iloc[missing_index, -1] = np.nan #using iloc
df1miss
# Out:
# nan

# %%
dff = df1[(df1.Geography == "France") & (df1.Exited == 1)]
dff
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602     Hargrave          619    France  Female   42
# 2             3    15619304         Onio          502    France  Female   42
# 35           36    15794171     Lombardo          475    France  Female   45
# 41           42    15738148       Clarke          465    France  Female   51
# 43           44    15755196       Lavine          834    France  Female   49
# ...         ...         ...          ...          ...       ...     ...  ...
# 9920       9921    15673020        Smith          678    France  Female   49
# 9947       9948    15732202   Abramovich          615    France    Male   34
# 9956       9957    15707861        Nucci          520    France  Female   46
# 9991       9992    15769959  Ajuluchukwu          597    France  Female   53
# 9997       9998    15584532          Liu          709    France  Female   36
#
# ...

# %%
dfbw = df1[(df1.Balance >=80000) & (df1.Balance <= 100000)]
dfbw
# Out:
#       RowNumber  CustomerId         Surname  CreditScore Geography  Gender  \
# 1             2    15647311            Hill          608     Spain  Female
# 31           32    15706552   Odinakachukwu          533    France    Male
# 54           55    15569590             Yoo          601   Germany    Male
# 69           70    15755648          Pisano          675    France  Female
# 80           81    15706021           Buley          665    France  Female
# ...         ...         ...             ...          ...       ...     ...
# 9965       9966    15690164            Shao          627   Germany  Female
# 9978       9979    15703563           P'eng          774    France    Male
# 9979       9980    15692664          Diribe          677    France  Female
# 9984       9985    15696175  Echezonachukwu          602   Germany    Male
# 9991       9992    15769959     Ajuluchukwu          597    France  Female
#
# ...

# %%
l1 = [4,6,9,10]
dfis = df1['Tenure'].isin([4,6,9,10])
#dfis = df1[df1.Tenure == 4,6,9,10 ]
dfis
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996     True
# 9997    False
# 9998    False
# 9999     True
# Name: Tenure, Length: 10000, dtype: bool

# %%
churn_rates = df1.groupby(['Geography', 'Gender'])['Exited'].mean()
churn_rates
# Out:
# Geography  Gender
# France     Female    0.203194
#            Male      0.127180
# Germany    Female    0.374790
#            Male      0.277989
# Spain      Female    0.211786
#            Male      0.131408
# Name: Exited, dtype: float64

# %%
df1[['Geography','Gender','Balance']].groupby(['Geography','Gender']).agg(['mean','count'])
# Out:
#                         Balance
#                            mean count
# Geography Gender
# France    Female   60322.670159  2261
#           Male     63546.284875  2753
# Germany   Female  119145.966471  1193
#           Male    120259.668222  1316
# Spain     Female   59862.092534  1089
#           Male     63352.833746  1388

# %%
df_summary = df1[['Geography','Exited','Balance']].groupby('Geography').agg({'Exited':'sum', 'Balance':'mean'})
df_summary
# Out:
#            Exited        Balance
# Geography
# France      808.0   62092.636516
# Germany     811.0  119730.116134
# Spain       412.0   61818.147763

# %%
group = np.random.randint(10, size=10000)
df1['Group'] = group
df1
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
#df1.drop('Group',1, inplace = True)
#df1.insert(3,'Group',group)
df1
# Out:
#       RowNumber  CustomerId    Surname  Group  CreditScore Geography  Gender  \
# 0             1    15634602   Hargrave      2          619    France  Female
# 1             2    15647311       Hill      7          608     Spain  Female
# 2             3    15619304       Onio      4          502    France  Female
# 3             4    15701354       Boni      1          699    France  Female
# 4             5    15737888   Mitchell      8          850     Spain  Female
# ...         ...         ...        ...    ...          ...       ...     ...
# 9995       9996    15606229   Obijiaku      8          771    France    Male
# 9996       9997    15569892  Johnstone      0          516    France    Male
# 9997       9998    15584532        Liu      0          709    France  Female
# 9998       9999    15682355  Sabbatini      7          772   Germany    Male
# 9999      10000    15628319     Walker      9          792    France  Female
#
# ...

# %%
df1['rank'] = df1['Balance'].rank(method='first',ascending=False).astype('int')
df1[['Balance','rank']]
# Out:
#         Balance   rank
# 0          0.00   6384
# 1      83807.86   5641
# 2     159660.80    589
# 3          0.00   6385
# 4     125510.82   2687
# ...         ...    ...
# 9995       0.00   9999
# 9996   57369.61   6260
# 9997       0.00  10000
# 9998   75075.31   5957
# 9999  130142.79   2271
#
# [10000 rows x 2 columns]

# %%
df1.Geography.nunique()
# Out:
# 3

# %%
print(df1['CreditScore'].value_counts())
# Out:
# 850    233
# 678     63
# 655     54
# 705     53
# 667     53
#       ...
# 404      1
# 351      1
# 365      1
# 417      1
# 419      1
# Name: CreditScore, Length: 460, dtype: int64
